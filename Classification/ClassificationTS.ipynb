# %% [markdown]
# #Montar ruta de drive

# %%
from google.colab import drive

drive.mount('/drive')
# Out:
# Mounted at /drive

# %% [markdown]
# #Sacar los Numpy

# %%
import numpy as np
from tqdm import tqdm

x_train = np.load('/drive/My Drive/Dataset_TrafficSignals/x_train_traffic.npy')
x_test = np.load('/drive/My Drive/Dataset_TrafficSignals/x_test_traffic.npy')

y_train = np.load('/drive/My Drive/Dataset_TrafficSignals/y_train_traffic.npy')
y_test = np.load('/drive/My Drive/Dataset_TrafficSignals/y_test_traffic.npy')



print(x_train.shape)
print(x_test.shape)
# Out:
# (26640, 32, 32, 3)
# (12630, 32, 32, 3)

# %% [markdown]
# ##Ejemplo de imagen

# %%
import matplotlib.pyplot as plt
import random
i = random.randint(0,26640)
im = x_train[i]
im_arr = np.asarray(im)
plt.imshow(im_arr)
print(list(y_train[i]).index(1))
# Out:
# 5

# %% [markdown]
# #Red Convolucional

# %%
from __future__ import print_function
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization as BN
from keras.layers import GaussianNoise as GN
from keras.optimizers import SGD
from keras.layers import Dropout
from keras.callbacks import LearningRateScheduler as LRS
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical

batch_size = 50
epochs = 100
num_classes = 43

#DATA AUGMENTATION#
datagen = ImageDataGenerator(
    width_shift_range=0.3,
    height_shift_range=0.3,
    rotation_range=20,
    zoom_range=[1.0,1.2],
    horizontal_flip=True)

#FUNCION QUE CREA LAS CAPAS DE CONVOLUCION#

def CBGN(model,filters,ishape=0):
  if (ishape!=0):
    model.add(Conv2D(filters, (3, 3), padding='same',
                 input_shape=ishape))
  else:
    model.add(Conv2D(filters, (3, 3), padding='same'))
  
  model.add(GN(0.1))
  model.add(Activation('relu'))
  model.add(BN())

  model.add(Conv2D(filters, (3, 3), padding='same'))
  model.add(GN(0.1))
  model.add(Activation('relu'))
  model.add(BN())

  model.add(Conv2D(filters, (3, 3), padding='same'))
  model.add(GN(0.1))
  model.add(Activation('relu'))
  model.add(BN())
  model.add(MaxPooling2D(pool_size=(2, 2)))
  
  
  return model

#CONFIGURACIÓN DE LA RED NEURONAL#
model = Sequential()

model=CBGN(model,32,x_train.shape[1:])
model=CBGN(model,64)
model=CBGN(model,128)
model=CBGN(model,256)
model=CBGN(model,512)

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.summary()

## DESCENSO POR GRADIENTE Y COMPILACIÓN
opt = SGD(lr=0.1, decay=1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

#LEARINING RATE ANNEALING#

def scheduler(epoch):
    if epoch < 50:
        return .1
    elif epoch < 75:
        return 0.01
    else:
        return 0.001

set_lr = LRS(scheduler)

## TRAINING
history=model.fit_generator(datagen.flow(x_train, y_train,batch_size=batch_size),
                            steps_per_epoch=len(x_train) / batch_size, 
                            epochs=epochs,
                            validation_data=(x_test, y_test),
                            callbacks=[set_lr],
                            verbose=1)

## TEST
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', round(scores[0],4))
print('Test accuracy:', round(scores[1],4))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 32, 32, 32)        0
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 32, 32, 32)        0
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# gaussian_noise_2 (GaussianNo (None, 32, 32, 32)        0
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# gaussian_noise_3 (GaussianNo (None, 16, 16, 64)        0
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# gaussian_noise_4 (GaussianNo (None, 16, 16, 64)        0
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# gaussian_noise_5 (GaussianNo (None, 16, 16, 64)        0
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# gaussian_noise_6 (GaussianNo (None, 8, 8, 128)         0
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# gaussian_noise_7 (GaussianNo (None, 8, 8, 128)         0
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# gaussian_noise_8 (GaussianNo (None, 8, 8, 128)         0
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# gaussian_noise_9 (GaussianNo (None, 4, 4, 256)         0
# _________________________________________________________________
# activation_9 (Activation)    (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# gaussian_noise_10 (GaussianN (None, 4, 4, 256)         0
# _________________________________________________________________
# activation_10 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# gaussian_noise_11 (GaussianN (None, 4, 4, 256)         0
# _________________________________________________________________
# activation_11 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 512)         1180160
# _________________________________________________________________
# gaussian_noise_12 (GaussianN (None, 2, 2, 512)         0
# _________________________________________________________________
# activation_12 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# gaussian_noise_13 (GaussianN (None, 2, 2, 512)         0
# _________________________________________________________________
# activation_13 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# gaussian_noise_14 (GaussianN (None, 2, 2, 512)         0
# _________________________________________________________________
# activation_14 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# activation_15 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                22059
# _________________________________________________________________
# activation_16 (Activation)   (None, 43)                0
# =================================================================
# Total params: 8,152,491
# Trainable params: 8,146,539
# Non-trainable params: 5,952
# _________________________________________________________________
# WARNING:tensorflow:From <ipython-input-4-a02067a9a767>:96: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 533/532 [==============================] - 38s 71ms/step - loss: 3.0764 - accuracy: 0.1486 - val_loss: 2.7758 - val_accuracy: 0.1648
# Epoch 2/100
# 533/532 [==============================] - 36s 68ms/step - loss: 2.1019 - accuracy: 0.3413 - val_loss: 1.8281 - val_accuracy: 0.4053
# Epoch 3/100
# 533/532 [==============================] - 36s 67ms/step - loss: 1.2644 - accuracy: 0.5680 - val_loss: 1.1150 - val_accuracy: 0.6629
# Epoch 4/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.7127 - accuracy: 0.7520 - val_loss: 0.7171 - val_accuracy: 0.7563
# Epoch 5/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.4257 - accuracy: 0.8555 - val_loss: 0.5110 - val_accuracy: 0.8576
# Epoch 6/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.3049 - accuracy: 0.8936 - val_loss: 0.4251 - val_accuracy: 0.8781
# Epoch 7/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.2337 - accuracy: 0.9171 - val_loss: 0.3997 - val_accuracy: 0.8843
# Epoch 8/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.1889 - accuracy: 0.9326 - val_loss: 0.3487 - val_accuracy: 0.8997
# Epoch 9/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.1576 - accuracy: 0.9423 - val_loss: 0.3533 - val_accuracy: 0.9052
# Epoch 10/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.1394 - accuracy: 0.9506 - val_loss: 0.3284 - val_accuracy: 0.9168
# Epoch 11/100
# 533/532 [==============================] - 36s 67ms/step - loss: 0.1212 - accuracy: 0.9557 - val_loss: 0.3335 - val_accuracy: 0.9184
# Epoch 12/100
# 533/532 [==============================] - 36s 67ms/step - loss: 0.1132 - accuracy: 0.9598 - val_loss: 0.2705 - val_accuracy: 0.9352
# Epoch 13/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0966 - accuracy: 0.9651 - val_loss: 0.3275 - val_accuracy: 0.9235
# Epoch 14/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0872 - accuracy: 0.9677 - val_loss: 0.3662 - val_accuracy: 0.9215
# Epoch 15/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0823 - accuracy: 0.9711 - val_loss: 0.3473 - val_accuracy: 0.9171
# Epoch 16/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0733 - accuracy: 0.9738 - val_loss: 0.4561 - val_accuracy: 0.9025
# Epoch 17/100
# 533/532 [==============================] - 35s 67ms/step - loss: 0.0662 - accuracy: 0.9777 - val_loss: 0.3681 - val_accuracy: 0.9193
# Epoch 18/100
# 533/532 [==============================] - 35s 67ms/step - loss: 0.0631 - accuracy: 0.9785 - val_loss: 0.3415 - val_accuracy: 0.9302
# Epoch 19/100
# 533/532 [==============================] - 36s 67ms/step - loss: 0.0568 - accuracy: 0.9806 - val_loss: 0.2974 - val_accuracy: 0.9475
# Epoch 20/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0545 - accuracy: 0.9820 - val_loss: 0.2885 - val_accuracy: 0.9423
# Epoch 21/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0560 - accuracy: 0.9808 - val_loss: 0.3488 - val_accuracy: 0.9344
# Epoch 22/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0525 - accuracy: 0.9827 - val_loss: 0.2710 - val_accuracy: 0.9435
# Epoch 23/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0494 - accuracy: 0.9840 - val_loss: 0.3165 - val_accuracy: 0.9468
# Epoch 24/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0466 - accuracy: 0.9843 - val_loss: 0.2736 - val_accuracy: 0.9448
# Epoch 25/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0406 - accuracy: 0.9857 - val_loss: 0.3414 - val_accuracy: 0.9330
# Epoch 26/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0372 - accuracy: 0.9878 - val_loss: 0.3126 - val_accuracy: 0.9460
# Epoch 27/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0355 - accuracy: 0.9887 - val_loss: 0.3295 - val_accuracy: 0.9437
# Epoch 28/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0387 - accuracy: 0.9872 - val_loss: 0.3544 - val_accuracy: 0.9356
# Epoch 29/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0355 - accuracy: 0.9885 - val_loss: 0.3637 - val_accuracy: 0.9281
# Epoch 30/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0355 - accuracy: 0.9887 - val_loss: 0.3799 - val_accuracy: 0.9390
# Epoch 31/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0311 - accuracy: 0.9894 - val_loss: 0.3317 - val_accuracy: 0.9437
# Epoch 32/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0298 - accuracy: 0.9911 - val_loss: 0.3378 - val_accuracy: 0.9383
# Epoch 33/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.3273 - val_accuracy: 0.9419
# Epoch 34/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0273 - accuracy: 0.9909 - val_loss: 0.3539 - val_accuracy: 0.9401
# Epoch 35/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0235 - accuracy: 0.9919 - val_loss: 0.3157 - val_accuracy: 0.9416
# Epoch 36/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0259 - accuracy: 0.9916 - val_loss: 0.3681 - val_accuracy: 0.9415
# Epoch 37/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.3139 - val_accuracy: 0.9490
# Epoch 38/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0274 - accuracy: 0.9914 - val_loss: 0.2994 - val_accuracy: 0.9463
# Epoch 39/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0232 - accuracy: 0.9920 - val_loss: 0.3269 - val_accuracy: 0.9458
# Epoch 40/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.3425 - val_accuracy: 0.9462
# Epoch 41/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0249 - accuracy: 0.9916 - val_loss: 0.3428 - val_accuracy: 0.9416
# Epoch 42/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0216 - accuracy: 0.9930 - val_loss: 0.3605 - val_accuracy: 0.9402
# Epoch 43/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 0.2950 - val_accuracy: 0.9422
# Epoch 44/100
# 533/532 [==============================] - 35s 65ms/step - loss: 0.0234 - accuracy: 0.9927 - val_loss: 0.3415 - val_accuracy: 0.9431
# Epoch 45/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0175 - accuracy: 0.9945 - val_loss: 0.2890 - val_accuracy: 0.9486
# Epoch 46/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0197 - accuracy: 0.9932 - val_loss: 0.3226 - val_accuracy: 0.9480
# Epoch 47/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0188 - accuracy: 0.9933 - val_loss: 0.3624 - val_accuracy: 0.9401
# Epoch 48/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 0.3500 - val_accuracy: 0.9474
# Epoch 49/100
# 533/532 [==============================] - 35s 65ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.3394 - val_accuracy: 0.9451
# Epoch 50/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0167 - accuracy: 0.9947 - val_loss: 0.4238 - val_accuracy: 0.9375
# Epoch 51/100
# 533/532 [==============================] - 35s 65ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.3387 - val_accuracy: 0.9500
# Epoch 52/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.3226 - val_accuracy: 0.9522
# Epoch 53/100
# 533/532 [==============================] - 35s 65ms/step - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.3135 - val_accuracy: 0.9529
# Epoch 54/100
# 533/532 [==============================] - 35s 65ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.3145 - val_accuracy: 0.9527
# Epoch 55/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.3227 - val_accuracy: 0.9521
# Epoch 56/100
# 533/532 [==============================] - 35s 65ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.3174 - val_accuracy: 0.9538
# Epoch 57/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.3183 - val_accuracy: 0.9534
# Epoch 58/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.3165 - val_accuracy: 0.9542
# Epoch 59/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.3120 - val_accuracy: 0.9551
# Epoch 60/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.3202 - val_accuracy: 0.9540
# Epoch 61/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.3197 - val_accuracy: 0.9546
# Epoch 62/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.3201 - val_accuracy: 0.9544
# Epoch 63/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.3198 - val_accuracy: 0.9542
# Epoch 64/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.3250 - val_accuracy: 0.9546
# Epoch 65/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.3236 - val_accuracy: 0.9553
# Epoch 66/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.3229 - val_accuracy: 0.9542
# Epoch 67/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.3290 - val_accuracy: 0.9541
# Epoch 68/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.3310 - val_accuracy: 0.9540
# Epoch 69/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.3271 - val_accuracy: 0.9541
# Epoch 70/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.3360 - val_accuracy: 0.9526
# Epoch 71/100
# 533/532 [==============================] - 35s 67ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.3320 - val_accuracy: 0.9530
# Epoch 72/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.3343 - val_accuracy: 0.9531
# Epoch 73/100
# 533/532 [==============================] - 35s 67ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.3331 - val_accuracy: 0.9536
# Epoch 74/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.3324 - val_accuracy: 0.9541
# Epoch 75/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.3344 - val_accuracy: 0.9526
# Epoch 76/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.3345 - val_accuracy: 0.9528
# Epoch 77/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.3341 - val_accuracy: 0.9525
# Epoch 78/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.3349 - val_accuracy: 0.9532
# Epoch 79/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.3334 - val_accuracy: 0.9529
# Epoch 80/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.3334 - val_accuracy: 0.9529
# Epoch 81/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.3329 - val_accuracy: 0.9533
# Epoch 82/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.3342 - val_accuracy: 0.9529
# Epoch 83/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.3346 - val_accuracy: 0.9529
# Epoch 84/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.3334 - val_accuracy: 0.9530
# Epoch 85/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.3333 - val_accuracy: 0.9533
# Epoch 86/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.3327 - val_accuracy: 0.9531
# Epoch 87/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.3340 - val_accuracy: 0.9533
# Epoch 88/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.3321 - val_accuracy: 0.9531
# Epoch 89/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.3345 - val_accuracy: 0.9531
# Epoch 90/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.3330 - val_accuracy: 0.9533
# Epoch 91/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.3328 - val_accuracy: 0.9530
# Epoch 92/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.3317 - val_accuracy: 0.9534
# Epoch 93/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.3344 - val_accuracy: 0.9534
# Epoch 94/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.3342 - val_accuracy: 0.9532
# Epoch 95/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.3352 - val_accuracy: 0.9530
# Epoch 96/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.3311 - val_accuracy: 0.9534
# Epoch 97/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.3326 - val_accuracy: 0.9534
# Epoch 98/100
# 533/532 [==============================] - 35s 65ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.3338 - val_accuracy: 0.9529
# Epoch 99/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.3313 - val_accuracy: 0.9537
# Epoch 100/100
# 533/532 [==============================] - 35s 66ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.3307 - val_accuracy: 0.9540
# 395/395 [==============================] - 5s 13ms/step - loss: 0.3307 - accuracy: 0.9540
# Test loss: 0.3307
# Test accuracy: 0.954

# %% [markdown]
# #Guardado del modelo de clasificación

# %%
model.save('/drive/My Drive/Dataset_TrafficSignals/classification_model.h5')
model.save_weights('/drive/My Drive/Dataset_TrafficSignals/classification_model_ONLY_WEIGHTS.h5')

# %% [markdown]
# #Ejemplo de predicción

# %%
i = random.randint(0,12630)
im = x_test[i]
im_arr = np.asarray(im)
plt.imshow(im_arr)
print(np.argmax(model.predict(np.asarray([x_test[i]])), axis=-1))
# Out:
# [5]
